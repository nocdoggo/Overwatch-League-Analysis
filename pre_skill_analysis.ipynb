# %%
import pandas as pd

# %% [markdown]
# function name: pre_cleansing
#
# Description:
#
# The function cleans the match statistics data and removes the ones that have low to no information for a given match。
#
# Input:
#
# 1. Match_stats [DataFrame]: It includes all the players' information for all matches of a given year.
#
# Output:
#
# 1. Match_stats_sanitized [DataFrame]: It includes the cleaned data.

# %%
phs_2019 = pd.read_csv('phs_2019_playoffs.csv')
phs_2019.head(10)
def pre_cleansing(Match_stats):
    # Remove unused columns
    Match_stats.drop(columns=['start_time','stage','map_type'],inplace=True)

    stat_copy = Match_stats.copy(deep=False)
    hero = Match_stats.iat[0,5]
    flag = False

    # Delete range
    range_begin = 0
    range_end = 0

    for index, row in Match_stats.iterrows():
        # If Alive Time < 50 sec
        if(row.stat_name == 'Time Alive'):
            if(row.stat_amount < 50):
                flag = True
        
        if(row.hero!= hero):  
            hero = row.hero
            range_end = index-1

        # If stat less than 6
            if((range_end-range_begin+1)< 3): 
                flag = True

            if(flag):
                stat_copy.drop(index = range(range_begin,range_end+1),inplace = True)
            range_begin = index
            flag = False
    # Remove All Heroes data
    stat_copy.drop(stat_copy[(stat_copy.hero == "All Heroes")].index, inplace=True) 
    return stat_copy

# %%
clean_df_2019 = pre_cleansing(phs_2019) 
clean_df_2019
# Out:
#         match_id               map_name    player              team  \
# 28         30172                  Ilios      Elsa   Chengdu Hunters
# 29         30172                  Ilios      Elsa   Chengdu Hunters
# 30         30172                  Ilios      Elsa   Chengdu Hunters
# 31         30172                  Ilios      Elsa   Chengdu Hunters
# 32         30172                  Ilios      Elsa   Chengdu Hunters
# ...          ...                    ...       ...               ...
# 103967     30157  Watchpoint: Gibraltar  Twilight  Vancouver Titans
# 103968     30157  Watchpoint: Gibraltar  Twilight  Vancouver Titans
# 103969     30157  Watchpoint: Gibraltar  Twilight  Vancouver Titans
# 103970     30157  Watchpoint: Gibraltar  Twilight  Vancouver Titans
# 103971     30157  Watchpoint: Gibraltar  Twilight  Vancouver Titans
#
#                     stat_name  hero   stat_amount
# 28            All Damage Done  D.Va  13934.906430
# 29                    Assists  D.Va     15.000000
# 30         Average Time Alive  D.Va    569.509017
# 31        Barrier Damage Done  D.Va   6703.071256
# 32      Critical Hit Accuracy  D.Va      0.092603
# ...                       ...   ...           ...
# 103967         Ultimates Used   Ana      6.000000
# 103968      Unscoped Accuracy   Ana      0.528777
# 103969          Unscoped Hits   Ana    147.000000
# 103970         Unscoped Shots   Ana    278.000000
# 103971        Weapon Accuracy   Ana      0.273504
#
# [65188 rows x 7 columns]

# %%
# number of different match_id
print('number of different match_id:', clean_df_2019.match_id.nunique())
# Out:
# number of different match_id: 18

# %%
# number of records in each match_id
clean_df_2019.match_id.value_counts()
# Out:
# 30175    6265
# 30163    4555
# 30154    4415
# 30173    4405
# 30156    4133
# 30151    4073
# 30176    4040
# 30172    4032
# 30152    3803
# 30153    3409
# 30155    3292
# 30162    3011
# 30164    2991
# 30159    2799
# 30157    2672
# 30160    2528
# 30161    2383
# 30158    2382
# Name: match_id, dtype: int64

# %%
match_result = pd.read_csv('annual_match_result_table.csv')
match_result
# Out:
#       match_year  match_id          map_name              map_winner  \
# 0           2018     10223            Dorado     Los Angeles Valiant
# 1           2018     10223  Temple of Anubis     Los Angeles Valiant
# 2           2018     10223             Ilios     Los Angeles Valiant
# 3           2018     10223           Numbani     Los Angeles Valiant
# 4           2018     10224            Dorado  Los Angeles Gladiators
# ...          ...       ...               ...                     ...
# 4511        2021     37442            Dorado           Atlanta Reign
# 4512        2021     37441             Ilios        Shanghai Dragons
# 4513        2021     37441          Hanamura        Shanghai Dragons
# 4514        2021     37441        King's Row        Shanghai Dragons
# 4515        2021     37441            Havana        Shanghai Dragons
#
#       winning_team_final_map_score  winning_team_win_rate  \
# 0                                3               0.600000
# 1                                4               0.571429
# 2                                2               0.666667
# 3                                2               0.666667
# 4                                1               1.000000
# ...                            ...                    ...
# 4511                             3               0.600000
# 4512                             2               1.000000
# 4513                             3               0.600000
# 4514                             6               0.545455
# 4515                             3               0.600000
#
#                 map_loser  losing_team_final_map_score  losing_team_win_rate
# 0     San Francisco Shock                            2              0.400000
# 1     San Francisco Shock                            3              0.428571
# 2     San Francisco Shock                            1              0.333333
# 3     San Francisco Shock                            1              0.333333
# 4        Shanghai Dragons                            0              0.000000
# ...                   ...                          ...                   ...
# 4511          Dallas Fuel                            2              0.400000
# 4512        Atlanta Reign                            0              0.000000
# 4513        Atlanta Reign                            2              0.400000
# 4514        Atlanta Reign                            5              0.454545
# 4515        Atlanta Reign                            2              0.400000
#
# [4516 rows x 9 columns]

# %%
def clean_match(hero_name, match_info):
    clean_match_df = match_info.merge(match_result.iloc[:, :6], how = 'inner', left_on =['match_id', 'map_name', 'team'], right_on =['match_id', 'map_name', 'map_winner'])
    hero_info = clean_match_df[clean_match_df['hero'] == hero_name]
    if len(hero_info) == 0:
        return 'No record about the hero name: ' + hero_name
    else:
        return hero_info
    
Dva_2019 = clean_match('D.Va',clean_df_2019)
Dva_2019
# Out:
#        match_id       map_name player              team  \
# 148       30172          Ilios  HOTBA  Guangzhou Charge
# 149       30172          Ilios  HOTBA  Guangzhou Charge
# 150       30172          Ilios  HOTBA  Guangzhou Charge
# 151       30172          Ilios  HOTBA  Guangzhou Charge
# 152       30172          Ilios  HOTBA  Guangzhou Charge
# ...         ...            ...    ...               ...
# 11950     30152  Lijiang Tower    Ria    Hangzhou Spark
# 11951     30152  Lijiang Tower    Ria    Hangzhou Spark
# 11952     30152  Lijiang Tower    Ria    Hangzhou Spark
# 11953     30152  Lijiang Tower    Ria    Hangzhou Spark
# 11954     30152  Lijiang Tower    Ria    Hangzhou Spark
#
#                               stat_name  hero  stat_amount  match_year  \
# 148                     All Damage Done  D.Va  2369.906080        2019
# 149                             Assists  D.Va     6.000000        2019
# 150               Critical Hit Accuracy  D.Va     0.025758        2019
# 151                       Critical Hits  D.Va    34.000000        2019
# 152                   Damage - Boosters  D.Va    48.851997        2019
# ...                                 ...   ...          ...         ...
# 11950            Time Building Ultimate  D.Va    56.875002        2019
# 11951  Time Elapsed per Ultimate Earned  D.Va   106.380884        2019
# 11952                       Time Played  D.Va    56.456796        2019
# 11953     Ultimates Earned - Fractional  D.Va     0.534636        2019
# 11954                   Weapon Accuracy  D.Va     0.278375        2019
#
#              map_winner  winning_team_final_map_score  winning_team_win_rate
# 148    Guangzhou Charge                             2               0.666667
# 149    Guangzhou Charge                             2               0.666667
# 150    Guangzhou Charge                             2               0.666667
# 151    Guangzhou Charge                             2               0.666667
# 152    Guangzhou Charge                             2               0.666667
# ...                 ...                           ...                    ...
# 11950    Hangzhou Spark                             2               0.666667
# 11951    Hangzhou Spark                             2               0.666667
# 11952    Hangzhou Spark                             2               0.666667
# 11953    Hangzhou Spark                             2               0.666667
# 11954    Hangzhou Spark                             2               0.666667
#
# [368 rows x 11 columns]

# %%
Top_11_stat_name = list(clean_df_2019.stat_name.value_counts()[:11].index)
Top_11_stat_name
# Out:
# ['Time Played',
#  'Time Building Ultimate',
#  'Time Alive',
#  'Ultimates Earned - Fractional',
#  'Time Elapsed per Ultimate Earned',
#  'Damage Taken',
#  'Healing Received',
#  'All Damage Done',
#  'Hero Damage Done',
#  'Average Time Alive',
#  'Barrier Damage Done']

# %%
# prepare the data for pivot
Dva_2019_bef_piv = Dva_2019[Dva_2019.stat_name.isin(Top_11_stat_name)].iloc[:, [0,1, 4, 6, 10]]
Dva_2019_bef_piv
# Out:
#        match_id       map_name                         stat_name  stat_amount  \
# 148       30172          Ilios                   All Damage Done  2369.906080
# 158       30172          Ilios                      Damage Taken  2709.025382
# 161       30172          Ilios                  Healing Received  2104.717705
# 162       30172          Ilios                  Hero Damage Done  2341.693555
# 174       30172          Ilios                        Time Alive   170.267005
# ...         ...            ...                               ...          ...
# 11949     30152  Lijiang Tower                        Time Alive    56.875002
# 11950     30152  Lijiang Tower            Time Building Ultimate    56.875002
# 11951     30152  Lijiang Tower  Time Elapsed per Ultimate Earned   106.380884
# 11952     30152  Lijiang Tower                       Time Played    56.456796
# 11953     30152  Lijiang Tower     Ultimates Earned - Fractional     0.534636
#
#        winning_team_win_rate
# 148                 0.666667
# 158                 0.666667
# 161                 0.666667
# 162                 0.666667
# 174                 0.666667
# ...                      ...
# 11949               0.666667
# 11950               0.666667
# 11951               0.666667
# 11952               0.666667
# 11953               0.666667
#
# [105 rows x 5 columns]

# %%
Dva_2019_bef_piv.winning_team_win_rate.value_counts()
# Out:
# 0.666667    62
# 0.750000    21
# 1.000000    11
# 0.555556    11
# Name: winning_team_win_rate, dtype: int64

# %%
Dva_2019_bef_piv.match_id.value_counts()
# Out:
# 30175    43
# 30151    22
# 30172    19
# 30173    11
# 30152    10
# Name: match_id, dtype: int64

# %%
Dva_2019_bef_piv[Dva_2019_bef_piv['match_id'] == 30151]
# Out:
#       match_id       map_name                         stat_name  stat_amount  \
# 8485     30151  Lijiang Tower                   All Damage Done  3714.039108
# 8487     30151  Lijiang Tower                Average Time Alive    63.048502
# 8488     30151  Lijiang Tower               Barrier Damage Done  1972.964939
# 8496     30151  Lijiang Tower                      Damage Taken  3194.083108
# 8501     30151  Lijiang Tower                  Healing Received  1732.191787
# 8502     30151  Lijiang Tower                  Hero Damage Done  1627.074170
# 8510     30151  Lijiang Tower                        Time Alive   126.097004
# 8511     30151  Lijiang Tower            Time Building Ultimate   140.965004
# 8512     30151  Lijiang Tower  Time Elapsed per Ultimate Earned    80.869725
# 8514     30151  Lijiang Tower                       Time Played   146.013389
# 8515     30151  Lijiang Tower     Ultimates Earned - Fractional     1.743112
# 9122     30151        Numbani                   All Damage Done  3701.293239
# 9124     30151        Numbani                Average Time Alive   105.975003
# 9125     30151        Numbani               Barrier Damage Done  1762.193718
# 9135     30151        Numbani                      Damage Taken  3075.597053
# 9140     30151        Numbani                  Healing Received  1314.049210
# 9141     30151        Numbani                  Hero Damage Done  1522.659515
# 9157     30151        Numbani                        Time Alive   211.950006
# 9158     30151        Numbani            Time Building Ultimate   199.515006
# 9159     30151        Numbani  Time Elapsed per Ultimate Earned    82.095797
# 9161     30151        Numbani                       Time Played   221.898750
# 9162     30151        Numbani     Ultimates Earned - Fractional     2.430271
#
#       winning_team_win_rate
# 8485               0.666667
# 8487               0.666667
# 8488               0.666667
# 8496               0.666667
# 8501               0.666667
# 8502               0.666667
# 8510               0.666667
# 8511               0.666667
# 8512               0.666667
# 8514               0.666667
# 8515               0.666667
# 9122               0.750000
# 9124               0.750000
# 9125               0.750000
# 9135               0.750000
# 9140               0.750000
# 9141               0.750000
# 9157               0.750000
# 9158               0.750000
# 9159               0.750000
# 9161               0.750000
# 9162               0.750000

# %%
# pivot the data for heat map
#Dva_2019_aft_piv = 
import numpy as np
pd.pivot_table(Dva_2019_bef_piv, values = ['stat_amount'], index = ['match_id', 'map_name','winning_team_win_rate'], columns = ['stat_name'])
# Out:
#                                                          stat_amount  \
# stat_name                                            All Damage Done
# match_id map_name              winning_team_win_rate
# 30151    Lijiang Tower         0.666667                  3714.039108
#          Numbani               0.750000                  3701.293239
# 30152    Lijiang Tower         0.666667                   635.605500
# 30172    Eichenwalde           0.666667                  1989.702972
#          Ilios                 0.666667                  2369.906080
# 30173    Lijiang Tower         0.666667                  6153.339690
# 30175    Dorado                0.750000                  2885.186710
#          Hanamura              1.000000                  5745.374824
#          Lijiang Tower         0.666667                  2089.249944
#          Watchpoint: Gibraltar 0.555556                 10068.111560
#
#                                                                          \
# stat_name                                            Average Time Alive
# match_id map_name              winning_team_win_rate
# 30151    Lijiang Tower         0.666667                       63.048502
#          Numbani               0.750000                      105.975003
# 30152    Lijiang Tower         0.666667                             NaN
# 30172    Eichenwalde           0.666667                      180.279006
#          Ilios                 0.666667                             NaN
# 30173    Lijiang Tower         0.666667                       60.505802
# 30175    Dorado                0.750000                             NaN
#          Hanamura              1.000000                      139.513671
#          Lijiang Tower         0.666667                       77.826002
#          Watchpoint: Gibraltar 0.555556                      224.181507
#
#                                                                           \
# stat_name                                            Barrier Damage Done
# match_id map_name              winning_team_win_rate
# 30151    Lijiang Tower         0.666667                      1972.964939
#          Numbani               0.750000                      1762.193718
# 30152    Lijiang Tower         0.666667                        92.266719
# 30172    Eichenwalde           0.666667                              NaN
#          Ilios                 0.666667                              NaN
# 30173    Lijiang Tower         0.666667                      3054.077865
# 30175    Dorado                0.750000                       410.652885
#          Hanamura              1.000000                      3167.141608
#          Lijiang Tower         0.666667                       982.235920
#          Watchpoint: Gibraltar 0.555556                      3780.705496
#
#                                                                    \
# stat_name                                            Damage Taken
# match_id map_name              winning_team_win_rate
# 30151    Lijiang Tower         0.666667               3194.083108
#          Numbani               0.750000               3075.597053
# 30152    Lijiang Tower         0.666667               1043.024597
# 30172    Eichenwalde           0.666667               2318.310134
#          Ilios                 0.666667               2709.025382
# 30173    Lijiang Tower         0.666667               6134.634609
# 30175    Dorado                0.750000               2096.771551
#          Hanamura              1.000000               6299.791434
#          Lijiang Tower         0.666667               2905.669602
#          Watchpoint: Gibraltar 0.555556               8049.090241
#
#                                                                        \
# stat_name                                            Healing Received
# match_id map_name              winning_team_win_rate
# 30151    Lijiang Tower         0.666667                   1732.191787
#          Numbani               0.750000                   1314.049210
# 30152    Lijiang Tower         0.666667                   1029.838488
# 30172    Eichenwalde           0.666667                   1444.670573
#          Ilios                 0.666667                   2104.717705
# 30173    Lijiang Tower         0.666667                   3206.354440
# 30175    Dorado                0.750000                   2064.648733
#          Hanamura              1.000000                   4422.336811
#          Lijiang Tower         0.666667                   1535.140724
#          Watchpoint: Gibraltar 0.555556                   6142.189122
#
#                                                                        \
# stat_name                                            Hero Damage Done
# match_id map_name              winning_team_win_rate
# 30151    Lijiang Tower         0.666667                   1627.074170
#          Numbani               0.750000                   1522.659515
# 30152    Lijiang Tower         0.666667                    543.338781
# 30172    Eichenwalde           0.666667                   1983.920591
#          Ilios                 0.666667                   2341.693555
# 30173    Lijiang Tower         0.666667                   2860.261825
# 30175    Dorado                0.750000                   2474.533824
#          Hanamura              1.000000                   2578.233216
#          Lijiang Tower         0.666667                   1107.014024
#          Watchpoint: Gibraltar 0.555556                   5792.604371
#
#                                                                   \
# stat_name                                             Time Alive
# match_id map_name              winning_team_win_rate
# 30151    Lijiang Tower         0.666667               126.097004
#          Numbani               0.750000               211.950006
# 30152    Lijiang Tower         0.666667                56.875002
# 30172    Eichenwalde           0.666667               180.279006
#          Ilios                 0.666667               170.267005
# 30173    Lijiang Tower         0.666667               302.529009
# 30175    Dorado                0.750000               176.042005
#          Hanamura              1.000000               418.541013
#          Lijiang Tower         0.666667               155.652005
#          Watchpoint: Gibraltar 0.555556               448.363014
#
#                                                                              \
# stat_name                                            Time Building Ultimate
# match_id map_name              winning_team_win_rate
# 30151    Lijiang Tower         0.666667                          140.965004
#          Numbani               0.750000                          199.515006
# 30152    Lijiang Tower         0.666667                           56.875002
# 30172    Eichenwalde           0.666667                          176.614005
#          Ilios                 0.666667                          136.836004
# 30173    Lijiang Tower         0.666667                          333.688010
# 30175    Dorado                0.750000                          129.310004
#          Hanamura              1.000000                          361.795011
#          Lijiang Tower         0.666667                          161.069005
#          Watchpoint: Gibraltar 0.555556                          273.602008
#
#                                                                                        \
# stat_name                                            Time Elapsed per Ultimate Earned
# match_id map_name              winning_team_win_rate
# 30151    Lijiang Tower         0.666667                                     80.869725
#          Numbani               0.750000                                     82.095797
# 30152    Lijiang Tower         0.666667                                    106.380884
# 30172    Eichenwalde           0.666667                                     98.566450
#          Ilios                 0.666667                                    395.329286
# 30173    Lijiang Tower         0.666667                                    103.702745
# 30175    Dorado                0.750000                                   1928.773370
#          Hanamura              1.000000                                    155.587098
#          Lijiang Tower         0.666667                                     42.473470
#          Watchpoint: Gibraltar 0.555556                                     73.279004
#
#                                                                   \
# stat_name                                            Time Played
# match_id map_name              winning_team_win_rate
# 30151    Lijiang Tower         0.666667               146.013389
#          Numbani               0.750000               221.898750
# 30152    Lijiang Tower         0.666667                56.456796
# 30172    Eichenwalde           0.666667               190.732145
#          Ilios                 0.666667               170.341407
# 30173    Lijiang Tower         0.666667               345.542249
# 30175    Dorado                0.750000               176.159193
#          Hanamura              1.000000               442.793301
#          Lijiang Tower         0.666667               165.452178
#          Watchpoint: Gibraltar 0.555556               462.405072
#
#
# stat_name                                            Ultimates Earned - Fractional
# match_id map_name              winning_team_win_rate
# 30151    Lijiang Tower         0.666667                                   1.743112
#          Numbani               0.750000                                   2.430271
# 30152    Lijiang Tower         0.666667                                   0.534636
# 30172    Eichenwalde           0.666667                                   1.791827
#          Ilios                 0.666667                                   0.346132
# 30173    Lijiang Tower         0.666667                                   3.217736
# 30175    Dorado                0.750000                                   0.067043
#          Hanamura              1.000000                                   2.325354
#          Lijiang Tower         0.666667                                   3.792226
#          Watchpoint: Gibraltar 0.555556                                   3.733703

# %%
# test dataset
# clean dataset for phs_2020_1
phs_2020 = pd.read_csv('phs_2020_1.csv')
phs_2020.head(10)
def pre_cleansing(Match_stats):
    # Remove unused columns
    Match_stats.drop(columns=['start_time','stage','map_type'],inplace=True)

    stat_copy = Match_stats.copy(deep=False)
    hero = Match_stats.iat[0,5]
    flag = False

    # Delete range
    range_begin = 0
    range_end = 0

    for index, row in Match_stats.iterrows():
        # If Alive Time < 50 sec
        if(row.stat_name == 'Time Alive'):
            if(row.stat_amount < 50):
                flag = True
        
        if(row.hero!= hero):
            hero = row.hero
            range_end = index-1

        # If stat less than 6
            if((range_end-range_begin+1)< 3): 
                flag = True

            if(flag):
                stat_copy.drop(index = range(range_begin,range_end+1),inplace = True)
            range_begin = index
            flag = False
    # Remove All Heroes data
    stat_copy.drop(stat_copy[(stat_copy.hero == "All Heroes")].index, inplace=True) 
    return stat_copy
clean_df_2020 = pre_cleansing(phs_2020) 
clean_df_2020
# Out:
#         match_id       map_name   player                 team  \
# 22         30991  Lijiang Tower  BenBest        Paris Eternal
# 23         30991  Lijiang Tower  BenBest        Paris Eternal
# 24         30991  Lijiang Tower  BenBest        Paris Eternal
# 25         30991  Lijiang Tower  BenBest        Paris Eternal
# 26         30991  Lijiang Tower  BenBest        Paris Eternal
# ...          ...            ...      ...                  ...
# 760106     34751         Rialto      eqo  Philadelphia Fusion
# 760107     34751         Rialto      eqo  Philadelphia Fusion
# 760108     34751         Rialto      eqo  Philadelphia Fusion
# 760109     34751         Rialto      eqo  Philadelphia Fusion
# 760110     34751         Rialto      eqo  Philadelphia Fusion
#
#                                stat_name       hero  stat_amount
# 22                       All Damage Done  Reinhardt  6674.164055
# 23                               Assists  Reinhardt    11.000000
# 24                    Average Time Alive  Reinhardt    60.199502
# 25                   Barrier Damage Done  Reinhardt  1875.000000
# 26                          Charge Kills  Reinhardt     1.000000
# ...                                  ...        ...          ...
# 760106                        Time Alive     Tracer     3.675000
# 760107            Time Building Ultimate     Tracer     3.675000
# 760108  Time Elapsed per Ultimate Earned     Tracer   308.700003
# 760109                       Time Played     Tracer     3.896239
# 760110     Ultimates Earned - Fractional     Tracer     0.011905
#
# [482951 rows x 7 columns]

# %%
# Top 11 stat_name in year 2019 
clean_df_2019.stat_name.value_counts()[:11]
# Out:
# Time Played                         1703
# Time Building Ultimate              1703
# Time Alive                          1703
# Ultimates Earned - Fractional       1701
# Time Elapsed per Ultimate Earned    1701
# Damage Taken                        1679
# Healing Received                    1677
# All Damage Done                     1658
# Hero Damage Done                    1656
# Average Time Alive                  1640
# Barrier Damage Done                 1612
# Name: stat_name, dtype: int64

# %%
# Top 11 stat_name in year 2020
clean_df_2020.stat_name.value_counts()[:11]
# Out:
# Time Alive                          12351
# Time Building Ultimate              12351
# Time Played                         12351
# Time Elapsed per Ultimate Earned    12339
# Ultimates Earned - Fractional       12339
# Damage Taken                        12135
# Healing Received                    12104
# All Damage Done                     12084
# Hero Damage Done                    12076
# Barrier Damage Done                 11909
# Average Time Alive                  11852
# Name: stat_name, dtype: int64

# %% [raw]
# There are 11 common stat_name with the highly appearance frequency. we will use these 11 stat_names to do analysis to see the relationhsip between each of them and the winning rate
