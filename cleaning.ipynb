# %%
import pandas as pd
phs_2019 = pd.read_csv('Data/2019/phs_2019_playoffs.csv')
phs_2019.head(10)
# Out:
#        start_time  match_id                              stage map_type  \
# 0  8/31/2019 1:09     30172  Overwatch League 2019 Post-Season  CONTROL
# 1  8/31/2019 1:09     30172  Overwatch League 2019 Post-Season  CONTROL
# 2  8/31/2019 1:09     30172  Overwatch League 2019 Post-Season  CONTROL
# 3  8/31/2019 1:09     30172  Overwatch League 2019 Post-Season  CONTROL
# 4  8/31/2019 1:09     30172  Overwatch League 2019 Post-Season  CONTROL
# 5  8/31/2019 1:09     30172  Overwatch League 2019 Post-Season  CONTROL
# 6  8/31/2019 1:09     30172  Overwatch League 2019 Post-Season  CONTROL
# 7  8/31/2019 1:09     30172  Overwatch League 2019 Post-Season  CONTROL
# 8  8/31/2019 1:09     30172  Overwatch League 2019 Post-Season  CONTROL
# 9  8/31/2019 1:09     30172  Overwatch League 2019 Post-Season  CONTROL
#
#   map_name player             team             stat_name        hero  \
# 0    Ilios   Elsa  Chengdu Hunters       All Damage Done  All Heroes
# 1    Ilios   Elsa  Chengdu Hunters               Assists  All Heroes
# 2    Ilios   Elsa  Chengdu Hunters    Average Time Alive  All Heroes
# 3    Ilios   Elsa  Chengdu Hunters   Barrier Damage Done  All Heroes
# 4    Ilios   Elsa  Chengdu Hunters  Damage - Quick Melee  All Heroes
# 5    Ilios   Elsa  Chengdu Hunters        Damage Blocked  All Heroes
# 6    Ilios   Elsa  Chengdu Hunters           Damage Done  All Heroes
# 7    Ilios   Elsa  Chengdu Hunters          Damage Taken  All Heroes
# 8    Ilios   Elsa  Chengdu Hunters                Deaths  All Heroes
# 9    Ilios   Elsa  Chengdu Hunters          Eliminations  All Heroes
#
#     stat_amount
# 0  19059.670270
# 1     22.000000
# 2    302.704223
# 3   8861.540116
# 4    152.999995
# 5  13699.766450
# 6  10122.130160
# 7  17295.539760
# 8      7.000000
# 9     35.000000

# %% [markdown]
# function name: pre_cleansing
#
# Description:
#
# The function cleans the match statistics data and removes the ones that have low to no information for a given match。
#
# Input:
#
# 1. Match_stats [DataFrame]: It includes all the players' information for all matches of a given year.
#
# Output:
#
# 1. Match_stats_sanitized [DataFrame]: It includes the cleaned data.

# %%
def pre_cleansing(Match_stats):
    # Remove unused columns
    Match_stats.drop(columns=['start_time','stage','map_type'],inplace=True)

    stat_copy = Match_stats.copy(deep=False)
    hero = Match_stats.iat[0,5]
    flag = False

    # Delete range
    range_begin = 0
    range_end = 0

    for index, row in Match_stats.iterrows():
        # If Alive Time < 50 sec
        if(row.stat_name == 'Time Alive'):
            if(row.stat_amount < 50):
                flag = True
        
        if(row.hero!= hero):
            hero = row.hero
            range_end = index-1

        # If stat less than 6
            if((range_end-range_begin+1)< 3): 
                flag = True

            if(flag):
                stat_copy.drop(index = range(range_begin,range_end+1),inplace = True)
            range_begin = index
            flag = False
    # Remove All Heroes data
    stat_copy.drop(stat_copy[(stat_copy.hero == "All Heroes")].index, inplace=True) 
    return stat_copy
pre_cleansing(phs_2019)
# Out:
#         match_id               map_name    player              team  \
# 28         30172                  Ilios      Elsa   Chengdu Hunters
# 29         30172                  Ilios      Elsa   Chengdu Hunters
# 30         30172                  Ilios      Elsa   Chengdu Hunters
# 31         30172                  Ilios      Elsa   Chengdu Hunters
# 32         30172                  Ilios      Elsa   Chengdu Hunters
# ...          ...                    ...       ...               ...
# 103967     30157  Watchpoint: Gibraltar  Twilight  Vancouver Titans
# 103968     30157  Watchpoint: Gibraltar  Twilight  Vancouver Titans
# 103969     30157  Watchpoint: Gibraltar  Twilight  Vancouver Titans
# 103970     30157  Watchpoint: Gibraltar  Twilight  Vancouver Titans
# 103971     30157  Watchpoint: Gibraltar  Twilight  Vancouver Titans
#
#                     stat_name  hero   stat_amount
# 28            All Damage Done  D.Va  13934.906430
# 29                    Assists  D.Va     15.000000
# 30         Average Time Alive  D.Va    569.509017
# 31        Barrier Damage Done  D.Va   6703.071256
# 32      Critical Hit Accuracy  D.Va      0.092603
# ...                       ...   ...           ...
# 103967         Ultimates Used   Ana      6.000000
# 103968      Unscoped Accuracy   Ana      0.528777
# 103969          Unscoped Hits   Ana    147.000000
# 103970         Unscoped Shots   Ana    278.000000
# 103971        Weapon Accuracy   Ana      0.273504
#
# [65188 rows x 7 columns]

# %%
phs_2020 = pd.read_csv('Data/2020/phs_2020_1.csv')
phs_2020.head(10)
# Out:
#        start_time  match_id                    stage map_type       map_name  \
# 0  2/8/2020 18:13     30991  OWL 2020 Regular Season  CONTROL  Lijiang Tower
# 1  2/8/2020 18:13     30991  OWL 2020 Regular Season  CONTROL  Lijiang Tower
# 2  2/8/2020 18:13     30991  OWL 2020 Regular Season  CONTROL  Lijiang Tower
# 3  2/8/2020 18:13     30991  OWL 2020 Regular Season  CONTROL  Lijiang Tower
# 4  2/8/2020 18:13     30991  OWL 2020 Regular Season  CONTROL  Lijiang Tower
# 5  2/8/2020 18:13     30991  OWL 2020 Regular Season  CONTROL  Lijiang Tower
# 6  2/8/2020 18:13     30991  OWL 2020 Regular Season  CONTROL  Lijiang Tower
# 7  2/8/2020 18:13     30991  OWL 2020 Regular Season  CONTROL  Lijiang Tower
# 8  2/8/2020 18:13     30991  OWL 2020 Regular Season  CONTROL  Lijiang Tower
# 9  2/8/2020 18:13     30991  OWL 2020 Regular Season  CONTROL  Lijiang Tower
#
#     player           team            stat_name        hero   stat_amount
# 0  BenBest  Paris Eternal      All Damage Done  All Heroes   6674.164055
# 1  BenBest  Paris Eternal              Assists  All Heroes     11.000000
# 2  BenBest  Paris Eternal   Average Time Alive  All Heroes     60.199502
# 3  BenBest  Paris Eternal  Barrier Damage Done  All Heroes   1875.000000
# 4  BenBest  Paris Eternal       Damage Blocked  All Heroes  14640.911780
# 5  BenBest  Paris Eternal          Damage Done  All Heroes   4798.164055
# 6  BenBest  Paris Eternal         Damage Taken  All Heroes   8267.621440
# 7  BenBest  Paris Eternal               Deaths  All Heroes      5.000000
# 8  BenBest  Paris Eternal         Eliminations  All Heroes     13.000000
# 9  BenBest  Paris Eternal          Final Blows  All Heroes      2.000000

# %%
cleaned_2020 = pre_cleansing(phs_2020)

# %%
cleaned_2020.head(10)
# Out:
#     match_id       map_name   player           team              stat_name  \
# 22     30991  Lijiang Tower  BenBest  Paris Eternal        All Damage Done
# 23     30991  Lijiang Tower  BenBest  Paris Eternal                Assists
# 24     30991  Lijiang Tower  BenBest  Paris Eternal     Average Time Alive
# 25     30991  Lijiang Tower  BenBest  Paris Eternal    Barrier Damage Done
# 26     30991  Lijiang Tower  BenBest  Paris Eternal           Charge Kills
# 27     30991  Lijiang Tower  BenBest  Paris Eternal        Damage - Charge
# 28     30991  Lijiang Tower  BenBest  Paris Eternal  Damage - Earthshatter
# 29     30991  Lijiang Tower  BenBest  Paris Eternal   Damage - Fire Strike
# 30     30991  Lijiang Tower  BenBest  Paris Eternal        Damage - Weapon
# 31     30991  Lijiang Tower  BenBest  Paris Eternal         Damage Blocked
#
#          hero   stat_amount
# 22  Reinhardt   6674.164055
# 23  Reinhardt     11.000000
# 24  Reinhardt     60.199502
# 25  Reinhardt   1875.000000
# 26  Reinhardt      1.000000
# 27  Reinhardt    150.000000
# 28  Reinhardt    315.000000
# 29  Reinhardt   2795.000000
# 30  Reinhardt   1538.164055
# 31  Reinhardt  14640.911780
